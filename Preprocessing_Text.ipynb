# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahafzsh/SentimentAnalysisForSTC/blob/main/Preprocessing_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("stc_tweets_after_final_cleaning_ver5.csv")
df
# Out:
#        Unnamed: 0                   id    created_at                 date  \
# 0               0  1353913978834051073  1.611633e+12  2021-01-26 03:53:41
# 1               1  1353709940901371904  1.611585e+12  2021-01-25 14:22:55
# 2               2  1353470988319653888  1.611528e+12  2021-01-24 22:33:24
# 3               3  1353426146621235201  1.611517e+12  2021-01-24 19:35:13
# 4               4  1353417040816713729  1.611515e+12  2021-01-24 18:59:02
# ...           ...                  ...           ...                  ...
# 10821       10826   551460881625014274  1.420313e+12  2015-01-03 19:31:34
# 10822       10827   551446748250787840  1.420310e+12  2015-01-03 18:35:24
# 10823       10828   551446022434877440  1.420310e+12  2015-01-03 18:32:31
# 10824       10829   550948181543227392  1.420191e+12  2015-01-02 09:34:17
# 10825       10830   550854981461737472  1.420169e+12  2015-01-02 03:23:56
#
#                    user_id                           name  retweet  nlikes  \
# 0                177757484                  NOHY✨ البراقة    False       0
# 1      1280687902364745731                            B..    False       2
# 2               2569667586                         A&....    False       0
# 3                584766522                    a7sas asmar    False       0
# 4                408119559                    Rehab. 👩🏻‍💻    False       0
# ...                    ...                            ...      ...     ...
# 10821            152641509  العناية بالعملاء stc السعودية    False       0
# 10822            152641509  العناية بالعملاء stc السعودية    False       0
# 10823            152641509  العناية بالعملاء stc السعودية    False       0
# 10824            152641509  العناية بالعملاء stc السعودية    False       0
# 10825            152641509  العناية بالعملاء stc السعودية    False       0
#
#        nreplies  nretweets                                             tweet4
# 0             1          0  سحبتو مني مبلغ لشحن رصيد طريق ماي اس سي تواصلت...
# 1             2          0  اذا رقمك شغال وعندك نسخه واتس اب السحابه بالوا...
# 2             1          0  اشتراك stc للمنصه روح ل stc واسالهم طريقته الا...
# 3             1          0  شوي وأحد يمنشني الله يسعدكم شكلي الليله مداوم ...
# 4             1          0                 اقدر اطلع بدل فاقد تطبيق ماي اس سي
# ...         ...        ...                                                ...
# 10821         0          0  مرحبا بإمكانك الاطلاع كمية البيانات المتبقيه ا...
# 10822         0          0  مرحبا لمعرفة عروض مسبق الدفع ارجو الإطلاع تطبي...
# 10823         0          0  مرحبا لمعرفة عروض مسبق الدفع ارجو الإطلاع تطبي...
# 10824         0          0  اهلا وسهلا , , , بامكانك الاطلاع تفاصيل الباقة...
# 10825         0          0  يمكنك معرفة المتبقي اشتراكك خلال موقع الجوال ن...
#
# [10826 rows x 11 columns]

# %%
df.head()
# Out:
#    Unnamed: 0                   id    created_at                 date  \
# 0           0  1353913978834051073  1.611633e+12  2021-01-26 03:53:41
# 1           1  1353709940901371904  1.611585e+12  2021-01-25 14:22:55
# 2           2  1353470988319653888  1.611528e+12  2021-01-24 22:33:24
# 3           3  1353426146621235201  1.611517e+12  2021-01-24 19:35:13
# 4           4  1353417040816713729  1.611515e+12  2021-01-24 18:59:02
#
#                user_id           name  retweet  nlikes  nreplies  nretweets  \
# 0            177757484  NOHY✨ البراقة    False       0         1          0
# 1  1280687902364745731            B..    False       2         2          0
# 2           2569667586         A&....    False       0         1          0
# 3            584766522    a7sas asmar    False       0         1          0
# 4            408119559    Rehab. 👩🏻‍💻    False       0         1          0
#
#                                               tweet4
# 0  سحبتو مني مبلغ لشحن رصيد طريق ماي اس سي تواصلت...
# 1  اذا رقمك شغال وعندك نسخه واتس اب السحابه بالوا...
# 2  اشتراك stc للمنصه روح ل stc واسالهم طريقته الا...
# 3  شوي وأحد يمنشني الله يسعدكم شكلي الليله مداوم ...
# 4                 اقدر اطلع بدل فاقد تطبيق ماي اس سي

# %%
df.tail()
# Out:
#        Unnamed: 0                  id    created_at                 date  \
# 10821       10826  551460881625014274  1.420313e+12  2015-01-03 19:31:34
# 10822       10827  551446748250787840  1.420310e+12  2015-01-03 18:35:24
# 10823       10828  551446022434877440  1.420310e+12  2015-01-03 18:32:31
# 10824       10829  550948181543227392  1.420191e+12  2015-01-02 09:34:17
# 10825       10830  550854981461737472  1.420169e+12  2015-01-02 03:23:56
#
#          user_id                           name  retweet  nlikes  nreplies  \
# 10821  152641509  العناية بالعملاء stc السعودية    False       0         0
# 10822  152641509  العناية بالعملاء stc السعودية    False       0         0
# 10823  152641509  العناية بالعملاء stc السعودية    False       0         0
# 10824  152641509  العناية بالعملاء stc السعودية    False       0         0
# 10825  152641509  العناية بالعملاء stc السعودية    False       0         0
#
#        nretweets                                             tweet4
# 10821          0  مرحبا بإمكانك الاطلاع كمية البيانات المتبقيه ا...
# 10822          0  مرحبا لمعرفة عروض مسبق الدفع ارجو الإطلاع تطبي...
# 10823          0  مرحبا لمعرفة عروض مسبق الدفع ارجو الإطلاع تطبي...
# 10824          0  اهلا وسهلا , , , بامكانك الاطلاع تفاصيل الباقة...
# 10825          0  يمكنك معرفة المتبقي اشتراكك خلال موقع الجوال ن...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10826 entries, 0 to 10825
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10826 non-null  int64
#  1   id          10826 non-null  int64
#  2   created_at  10826 non-null  float64
#  3   date        10826 non-null  object
#  4   user_id     10826 non-null  int64
#  5   name        10826 non-null  object
#  6   retweet     10826 non-null  bool
#  7   nlikes      10826 non-null  int64
#  8   nreplies    10826 non-null  int64
#  9   nretweets   10826 non-null  int64
#  10  tweet4      10824 non-null  object
# dtypes: bool(1), float64(1), int64(6), object(3)
# memory usage: 856.5+ KB
